# %% [markdown]
# # EDA -AUTOMOBILE DATASET

# %% [markdown]
# Analyze the automobile dataset using pandas and numpy.
# visualise it using matplotlib.

# %% [markdown]
# Initially there are some variables hold "?" in the dataset.
# Those features are
# normalise-losses,
# price,
# horse-power,
# peak-rpm,
# bore.

# %% [markdown]
# Replace the corresponding "?" of the feature with the mean() value.
# For the variable num-of-doors replace "?" with the mode.
# Here there is a meaningfull insight that could derived from the dataset.

# %% [markdown]
# # visualisations and its insights

# %%
import IPython.display
from IPython.display import Image

# %% [markdown]
# Heamap is used to visualise the correlation between continuous variable

# %%
Image("/Users/Nandhini/Documents/heatmap_auto.png")

# %% [markdown]
# correlation between Engine-size & peak-rpm

# %%
Image("/Users/Nandhini/Documents/correl.png")

# %% [markdown]
# Nearly 90.24% of  people prefer fuel-type of vehicle as gas

# %%
Image("/Users/Nandhini/Documents/fuel type vehicle.png")

# %% [markdown]
# Among all the vehicle Toyota is the highly preferred vehicle

# %%
Image("/Users/Nandhini/Documents/toyato.png")

# %% [markdown]
# Price of Porsche,BMW,Mercedes-Benz are very high.Porsche offer lot of model in high price range.
# BMW and Mercedes Benz have only car with high price

# %%
Image("/Users/Nandhini/Documents/all vehicles.png")
