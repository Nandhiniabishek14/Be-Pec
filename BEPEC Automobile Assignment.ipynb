# %%
import pandas as pd
import numpy as np

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mb
import seaborn as sn

# %%
auto_data=pd.read_csv("/Users/Nandhini/Documents/Automobile price data _Raw_.csv")

# %%
auto_data.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
auto_data.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
auto_data.shape
# Out:
# (205, 26)

# %%
list(auto_data)
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
auto_data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
auto_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
auto_data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
auto_data["price"].unique
# Out:
# <bound method Series.unique of 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: object>

# %%
median=auto_data[auto_data["price"]!="?"]["price"].astype(dtype="float").median()

# %%
auto_data["price"]=auto_data["price"].str.replace("?",str(median)).astype(dtype="float")
# Out:
# /var/folders/z7/cl1747pn4p5885t_s8v4fn2w0000gp/T/ipykernel_89217/2885102141.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   auto_data["price"]=auto_data["price"].str.replace("?",str(median)).astype(dtype="float")

# %%
auto_data["price"]
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
mean=auto_data[auto_data["normalized-losses"]!="?"]["normalized-losses"].astype(dtype="float").mean()

# %%
auto_data["normalized-losses"].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
auto_data["normalized-losses"].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: normalized-losses, dtype: int64

# %%
auto_data["normalized-losses"]=auto_data["normalized-losses"].str.replace("?",str(mean)).astype(dtype="float")
# Out:
# /var/folders/z7/cl1747pn4p5885t_s8v4fn2w0000gp/T/ipykernel_89217/3950206216.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   auto_data["normalized-losses"]=auto_data["normalized-losses"].str.replace("?",str(mean)).astype(dtype="float")

# %%
#normalised-losses histogram
mb.hist(auto_data["normalized-losses"].astype(dtype="float"),bins=15)
# Out:
# (array([11., 16., 36., 20., 61., 11., 19., 15.,  5.,  5.,  4.,  0.,  0.,
#          1.,  1.]),
#  array([ 65.        ,  77.73333333,  90.46666667, 103.2       ,
#         115.93333333, 128.66666667, 141.4       , 154.13333333,
#         166.86666667, 179.6       , 192.33333333, 205.06666667,
#         217.8       , 230.53333333, 243.26666667, 256.        ]),
#  <BarContainer object of 15 artists>)

# %%
auto_data["horsepower"].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', '?', '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
mean=auto_data[auto_data["horsepower"]!="?"]["horsepower"].astype(dtype="float").mean()

# %%
auto_data["horsepower"]=auto_data["horsepower"].str.replace("?",str(mean)).astype(dtype="float")
# Out:
# /var/folders/z7/cl1747pn4p5885t_s8v4fn2w0000gp/T/ipykernel_89217/817582779.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   auto_data["horsepower"]=auto_data["horsepower"].str.replace("?",str(mean)).astype(dtype="float")

# %%
auto_data["horsepower"].value_counts()
# Out:
# 68.000000     19
# 70.000000     11
# 69.000000     10
# 116.000000     9
# 110.000000     8
# 95.000000      7
# 88.000000      6
# 62.000000      6
# 101.000000     6
# 160.000000     6
# 114.000000     6
# 84.000000      5
# 97.000000      5
# 102.000000     5
# 145.000000     5
# 82.000000      5
# 76.000000      5
# 111.000000     4
# 92.000000      4
# 123.000000     4
# 86.000000      4
# 90.000000      3
# 73.000000      3
# 85.000000      3
# 207.000000     3
# 182.000000     3
# 121.000000     3
# 152.000000     3
# 112.000000     2
# 56.000000      2
# 161.000000     2
# 156.000000     2
# 94.000000      2
# 52.000000      2
# 104.256158     2
# 162.000000     2
# 155.000000     2
# 184.000000     2
# 100.000000     2
# 176.000000     2
# 55.000000      1
# 262.000000     1
# 134.000000     1
# 115.000000     1
# 140.000000     1
# 48.000000      1
# 58.000000      1
# 60.000000      1
# 78.000000      1
# 135.000000     1
# 200.000000     1
# 64.000000      1
# ...

# %%
auto_data["peak-rpm"].unique
# Out:
# <bound method Series.unique of 0      5000
# 1      5000
# 2      5000
# 3      5500
# 4      5500
#        ...
# 200    5400
# 201    5300
# 202    5500
# 203    4800
# 204    5400
# Name: peak-rpm, Length: 205, dtype: object>

# %%
mean=auto_data[auto_data["peak-rpm"]!="?"]["peak-rpm"].astype(dtype="float").mean()

# %%
auto_data["peak-rpm"]=auto_data["peak-rpm"].str.replace("?",str(mean)).astype(dtype="float")
# Out:
# /var/folders/z7/cl1747pn4p5885t_s8v4fn2w0000gp/T/ipykernel_89217/3685580270.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   auto_data["peak-rpm"]=auto_data["peak-rpm"].str.replace("?",str(mean)).astype(dtype="float")

# %%
auto_data["peak-rpm"].unique
# Out:
# <bound method Series.unique of 0      5000.0
# 1      5000.0
# 2      5000.0
# 3      5500.0
# 4      5500.0
#         ...
# 200    5400.0
# 201    5300.0
# 202    5500.0
# 203    4800.0
# 204    5400.0
# Name: peak-rpm, Length: 205, dtype: float64>

# %%
mean=auto_data[auto_data["bore"]!="?"]["bore"].astype(dtype="float").mean()

# %%
auto_data["bore"]=auto_data["bore"].str.replace("?",str(mean)).astype(dtype="float")
# Out:
# /var/folders/z7/cl1747pn4p5885t_s8v4fn2w0000gp/T/ipykernel_89217/2545482919.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   auto_data["bore"]=auto_data["bore"].str.replace("?",str(mean)).astype(dtype="float")

# %%
auto_data["bore"].unique
# Out:
# <bound method Series.unique of 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 200    3.78
# 201    3.78
# 202    3.58
# 203    3.01
# 204    3.78
# Name: bore, Length: 205, dtype: float64>

# %%
mode1=auto_data[auto_data["num-of-doors"]!="?"]["num-of-doors"].mode()

# %%
auto_data["num-of-doors"]=auto_data["num-of-doors"].str.replace("?",str(mode1))
# Out:
# /var/folders/z7/cl1747pn4p5885t_s8v4fn2w0000gp/T/ipykernel_89217/3635528243.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   auto_data["num-of-doors"]=auto_data["num-of-doors"].str.replace("?",str(mode1))

# %%
auto_data["num-of-doors"].value_counts()
# Out:
# four                                            114
# two                                              89
# 0    four\nName: num-of-doors, dtype: object      2
# Name: num-of-doors, dtype: int64

# %%
list(auto_data)
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
auto_data.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          31.681008    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.300000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore  compression-ratio  \
# count  205.000000   205.000000   205.000000  205.000000         205.000000
# mean    53.724878  2555.565854   126.907317    3.329751          10.142537
# std      2.443522   520.680204    41.642693    0.270844           3.972040
# ...

# %%
corr=auto_data.corr()
# Out:
# /var/folders/z7/cl1747pn4p5885t_s8v4fn2w0000gp/T/ipykernel_89217/2384939812.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=auto_data.corr()

# %%
corr
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.465190   -0.531954 -0.357612
# normalized-losses   0.465190           1.000000   -0.056518  0.019209
# wheel-base         -0.531954          -0.056518    1.000000  0.874587
# length             -0.357612           0.019209    0.874587  1.000000
# width              -0.232919           0.084195    0.795144  0.841118
# height             -0.541038          -0.370706    0.589435  0.491029
# curb-weight        -0.227691           0.097785    0.776386  0.877728
# engine-size        -0.105790           0.110997    0.569329  0.683360
# bore               -0.130083          -0.029266    0.488760  0.606462
# compression-ratio  -0.178515          -0.114525    0.249786  0.158414
# horsepower          0.071389           0.203434    0.351957  0.554434
# peak-rpm            0.273679           0.237748   -0.360704 -0.287031
# ...

# %%
mb.figure(figsize=(10,10))
b=sn.heatmap(corr,annot=True,fmt=".2f")

# %%
mb.title('correlation between')
mb.scatter(auto_data['engine-size'],auto_data['peak-rpm'])

# %%
xer=sn.boxplot(x="drive-wheels",y="price",data=auto_data)

# %%
mb.title('Making price')
mb.rcParams["figure.figsize"]=(20,10)
axr=sn.boxplot(x="make",y="price",data=auto_data)

# %%
auto_data["engine-size"].value_counts().plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
auto_data["engine-location"].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
auto_data["make"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
auto_data["fuel-type"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
auto_data["fuel-type"].value_counts().plot.pie(autopct="%.2f")
# Out:
# <AxesSubplot: ylabel='fuel-type'>

# %%
auto_data["aspiration"].value_counts().plot.pie(autopct="%.2f")
# Out:
# <AxesSubplot: ylabel='aspiration'>

# %%
auto_data["drive-wheels"].value_counts().plot.pie(autopct="%.2f")
# Out:
# <AxesSubplot: ylabel='drive-wheels'>

# %%
auto_data["num-of-doors"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >
